# %% [markdown]
# # Tvorba strukturovaných sítí

# %%
using PyPlot;

# %%
function channel(n,m)
    x = zeros(n,m);  y = zeros(n,m)
    
    x[1,:] = 0.0; y[1,:] = linspace(0,1,m)
    x[n,:] = 3.0; y[n,:] = linspace(0,1,m)
    x[:,m] = linspace(0,3,n); y[:,m] = 1.0
    
    length = 2 + π/2
    ds = length / (n-1)
    for i in 1:n
        s = (i-1) * ds
        if s < 1   
            x[i,1] = s; y[i,1] = 0;
        elseif s < 1 + π/2
            ϕ = 2*(s - 1)
            x[i,1] = 1.5 - 0.5*cos(ϕ)
            y[i,1] = 0.5*sin(ϕ)
        else
            x[i,1] = s + 1 - π/2; y[i,1] = 0
        end
    end
    return x,y
end
# Out:
# channel (generic function with 1 method)

# %%
function channel_ns(n,m)
    x = zeros(n,m);  y = zeros(n,m)
    
    x[1,:] = 0.0; y[1,:] = linspace(0,1,m).^3
    x[n,:] = 3.0; y[n,:] = linspace(0,1,m).^3
    x[:,m] = linspace(0,3,n); y[:,m] = 1.0
    
    length = 2 + π/2
    ds = length / (n-1)
    for i in 1:n
        s = (i-1) * ds
        if s < 1   
            x[i,1] = s; y[i,1] = 0;
        elseif s < 1 + π/2
            ϕ = 2*(s - 1)
            x[i,1] = 1.5 - 0.5*cos(ϕ)
            y[i,1] = 0.5*sin(ϕ)
        else
            x[i,1] = s + 1 - π/2; y[i,1] = 0
        end
    end
    return x,y
end
# Out:
# channel_ns (generic function with 1 method)

# %%
function curved_rectangle(n,m)
    x = zeros(n,m);  y = zeros(n,m)
    
    x[:,1] = linspace(0,1,n)
    y[:,1] = (x[:,1] - 0.5).^2/2 - 0.125

    x[:,end] = linspace(0,1,n)
    y[:,end] = 1.125 - (x[:,1] - 0.5).^2/2

    y[1,:] = linspace(0,1,m)
    x[1,:] = 0.125 - (y[1,:] - 0.5).^2/2

    y[end,:] = linspace(0,1,m)
    x[end,:] = 1.125 - (y[end,:] - 0.5).^2/2

    return x,y
end
# Out:
# curved_rectangle (generic function with 1 method)

# %%
function plot_boundary(x,y)
    plot(x[1,:], y[1,:], "-xr")
    plot(x[end,:], y[end,:], "-xr")
    plot(x[:,1], y[:,1], "-xr")
    plot(x[:,end], y[:,end], "-xr")
    axis("equal");
end;

function plot_mesh(x,y)
    n,m = size(x)
    for i=2:n-1
        plot(x[i,:], y[i,:], "-b")
    end
    for j=2:m-1
        plot(x[:,j], y[:,j], "-b")
    end
    plot_boundary(x,y);
end;

# %%
chx,chy = channel(30,10);
plot_boundary(chx,chy);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f43693fb6d0>)

# %%
crx,cry = curved_rectangle(20,20);
plot_boundary(crx,cry);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f4368e52290>)

# %% [markdown]
# ## Algebraická síť

# %% [markdown]
# ### Jednosměrná interpolace

# %%
function straight_j!(x,y)
    n,m = size(x)
    for j = 2:m-1
        η = (j-1) / (m-1)
        x[2:n-1,j] = (1-η) * x[2:n-1,1] + η * x[2:n-1,end]
        y[2:n-1,j] = (1-η) * y[2:n-1,1] + η * y[2:n-1,end]
    end
end
# Out:
# WARNING: Method definition straight_j!(Any, Any) in module Main at In[7]:2 overwritten at In[9]:2.
# straight_j! (generic function with 1 method)

# %%
straight_j!(chx,chy);
plot_mesh(chx,chy);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f4368d3e350>)

# %%
plot_mesh(x,y)
# Out:
# UndefVarError: x not defined

# %%
straight_j!(crx,cry);
plot_mesh(crx,cry);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f4368d103d0>)

# %% [markdown]
# ### Transfinitní interpolace

# %%
function linear_tfi!(x,y)
    n,m = size(x)
    
    for i=2:n-1
        ξ = (i-1) / (n-1)
        for j=2:m-1
            η = (j-1) / (m-1)
            
            ux = (1-ξ) * x[1,j] + ξ * x[n,j]
            uy = (1-ξ) * y[1,j] + ξ * y[n,j]

            vx = (1-η) * x[i,1] + η * x[i,m]
            vy = (1-η) * y[i,1] + η * y[i,m]
            
            uvx = (1-ξ)*(1-η) * x[1,1] + ξ*(1-η) * x[n,1] + (1-ξ)*η * x[1,m] + ξ*η * x[n,m]
            uvy = (1-ξ)*(1-η) * y[1,1] + ξ*(1-η) * y[n,1] + (1-ξ)*η * y[1,m] + ξ*η * y[n,m]
            
            x[i,j] = ux + vx - uvx
            y[i,j] = uy + vy - uvy            
        end
    end
end
# Out:
# linear_tfi! (generic function with 1 method)

# %%
linear_tfi!(crx,cry);
plot_mesh(crx,cry);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f4368d29990>)

# %%
nsx,nsy = channel_ns(30,10);
plot_boundary(nsx,nsy);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f43651bb210>)

# %%
linear_tfi!(nsx,nsy);
plot_mesh(nsx,nsy);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f4365339f10>)

# %% [markdown]
# ## Eliptický generátor
#
# \begin{align*}
#     \Delta \xi(x,y) &= p(x,y), \\
#     \Delta \eta(x,y) &= q(x,y)
# \end{align*}
#
# Transformace prvních derivací:
#
# \begin{align*}
#     \frac{\partial}{\partial x} &=
#     \frac{\partial}{\partial \xi} \frac{\partial \xi}{\partial x} +
#     \frac{\partial}{\partial \eta} \frac{\partial \eta}{\partial x}, \\
#     \frac{\partial}{\partial y} &=
#     \frac{\partial}{\partial \xi} \frac{\partial \xi}{\partial y} +
#     \frac{\partial}{\partial \eta} \frac{\partial \eta}{\partial y}.
# \end{align*}
#
# Transformace druhých derivací:
#
# \begin{align*}
#     \frac{\partial^2}{\partial x^2} &=
#     \frac{\partial^2}{\partial \xi^2} \left(\frac{\partial \xi}{\partial x}\right)^2 +
#     2 \frac{\partial^2}{\partial \eta \partial \xi} \frac{\partial \xi}{\partial x}\frac{\partial \eta}{\partial x} +
#     \frac{\partial^2}{\partial \eta^2} \left(\frac{\partial \eta}{\partial x}\right)^2,
#     \\
#     \frac{\partial^2}{\partial y^2} &=
#     \frac{\partial^2}{\partial \xi^2} \left(\frac{\partial \xi}{\partial y}\right)^2 +
#     2 \frac{\partial^2}{\partial \eta \partial \xi} \frac{\partial \xi}{\partial y}\frac{\partial \eta}{\partial y} +
#     \frac{\partial^2}{\partial \eta^2} \left(\frac{\partial \eta}{\partial y}\right)^2.
# \end{align*}

# %% [markdown]
# Laplaceův operátor v křivočarých souřadnicích
#
# $$
#     \Delta \phi(\xi,\eta) =
#     (\nabla \xi \cdot \nabla \xi)\, \phi_{\xi\xi} +
#     2(\nabla\xi\cdot\nabla\eta)\, \phi_{\xi\eta} +
#     (\nabla \eta \cdot \nabla \eta)\, \phi_{\eta\eta}
# $$
